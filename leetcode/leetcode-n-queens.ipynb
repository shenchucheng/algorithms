# %% [markdown]
# # [**51. N 皇后**](https://leetcode-cn.com/problems/n-queens)
#
# n 皇后问题研究的是如何将 n 个皇后放置在 n×n 的棋盘上，并且使皇后彼此之间不能相互攻击。
# 上图为 8 皇后问题的一种解法。
#
# 给定一个整数 n，返回所有不同的 n 皇后问题的解决方案。
#
# 每一种解法包含一个明确的 n 皇后问题的棋子放置方案，该方案中 'Q' 和 '.' 分别代表了皇后和空位。
#
#
#
# 示例：
#
# 输入：4
# 输出：[
#  [".Q..",  // 解法 1
#   "...Q",
#   "Q...",
#   "..Q."],
#
#  ["..Q.",  // 解法 2
#   "Q...",
#   "...Q",
#   ".Q.."]
# ]
# 解释: 4 皇后问题存在两个不同的解法。
#
#
# 提示：
#
# 皇后彼此不能相互攻击，也就是说：任何两个皇后都不能处于同一条横行、纵行或斜线上。
# 通过次数60,875提交次数85,510

# %%
class Solution:
    def solveNQueens(self, n: int) -> List[List[str]]:
        if n == 0:
            return [[]]
        if n == 1:
            return [['Q']]
        ans = []
        test = []
        res = [_ for _ in range(1,n)]
        k = 0
        while 1:
            l = len(test)
            for i in test:
                if abs(k-i) == l:
                    break
                else:
                    l -= 1
            if l == 0:
                test.append(k)
                if res:
                    k = min(res)
                    res.remove(k)
                    continue
                else:
                    ans.append(test)
                    test = test.copy()
                    res.append(test.pop())
                    k = test.pop()
            while 1:
                res.sort()
                for i in res:
                    if i>k:
                        res.remove(i)
                        res.append(k)
                        k = i 
                        break
                if i == k:
                    break
                else:
                    try:
                        res.append(k)
                        k = test.pop()
                    except:
                        return getans(ans, n)
        return getans(ans, n)


def getans(ans, n):
    boards = []
    for i in ans:
        board = []
        for j in i:
            a = ['.']*n
            a[j] = 'Q'
            board.append(a)
        board = map(lambda x: ''.join(x), board)
        boards.append(list(board))
    return boards

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - [N皇后 leetcode](https://leetcode-cn.com/problems/n-queens/solution/nhuang-hou-by-leetcode-solution/)
# - [N皇后，经典回溯算法（图文详解)](https://leetcode-cn.com/problems/n-queens/solution/nhuang-hou-jing-dian-hui-su-suan-fa-tu-wen-xiang-j/)
# - [回溯算法（转换成全排列问题 + 剪枝）- 题解后有相关问题](https://leetcode-cn.com/problems/n-queens/solution/gen-ju-di-46-ti-quan-pai-lie-de-hui-su-suan-fa-si-/)
